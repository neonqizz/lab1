# %% [markdown]
# <a href="https://colab.research.google.com/github/neonqizz/lab1/blob/main/laba1_finish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data_path = "/content/file1.data"
data = np.genfromtxt(data_path, delimiter=",")
print(data)
# Out:
# [[1.18000e+02 8.06331e+00 6.90000e+01         nan]
#  [6.10000e+01 5.46451e+00 2.00000e+00         nan]
#  [1.21000e+02 4.47084e+00 3.10000e+01         nan]
#  [1.42000e+02 5.86238e+00 1.59000e+02         nan]
#  [5.20000e+01 4.32689e+00 1.27000e+02         nan]
#  [1.77000e+02 9.45185e+00 4.10000e+01         nan]
#  [2.50000e+01 4.65878e+00 1.58000e+02         nan]
#  [1.82000e+02 9.22393e+00 9.90000e+01         nan]
#  [1.90000e+02 8.97034e+00 9.00000e+00         nan]
#  [3.60000e+01 7.56081e-01 1.38000e+02         nan]
#  [7.80000e+01 2.33089e+00 3.80000e+01         nan]
#  [6.00000e+01 3.92869e-01 7.90000e+01         nan]
#  [1.22000e+02 8.78341e+00 1.51000e+02         nan]
#  [1.08000e+02 6.51350e+00 1.46000e+02         nan]
#  [1.35000e+02 6.52116e-01 6.80000e+01         nan]
#  [1.51000e+02 2.44352e+00 2.80000e+01         nan]
#  [9.20000e+01 4.47018e+00 1.54000e+02         nan]
#  [1.58000e+02 1.00826e+01 3.60000e+01         nan]
# ...

# %%
print ( "Data type : ", type(data) )
print ( "Data shape : ", data.shape )
print ( data[-4:] )
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (210, 4)
# [[ 39.        1.13591 138.            nan]
#  [136.       14.5855  274.            nan]
#  [ 15.        5.68812 214.            nan]
#  [154.       12.7016  191.            nan]]

# %%
data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][1]), type(data1[0][3]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (210,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.bytes_'>
# Dataset:
# [(118,  8.06331  ,  69, b' bomj') ( 61,  5.46451  ,   2, b' bomj')
#  (121,  4.47084  ,  31, b' bomj') (142,  5.86238  , 159, b' bomj')
#  ( 52,  4.32689  , 127, b' bomj') (177,  9.45185  ,  41, b' bomj')
#  ( 25,  4.65878  , 158, b' bomj') (182,  9.22393  ,  99, b' bomj')
#  (190,  8.97034  ,   9, b' bomj') ( 36,  0.756081 , 138, b' bomj')
#  ( 78,  2.33089  ,  38, b' bomj') ( 60,  0.392869 ,  79, b' bomj')
#  (122,  8.78341  , 151, b' bomj') (108,  6.5135   , 146, b' bomj')
#  (135,  0.652116 ,  68, b' bomj') (151,  2.44352  ,  28, b' bomj')
#  ( 92,  4.47018  , 154, b' bomj') (158, 10.0826   ,  36, b' bomj')
#  (192,  8.17428  , 100, b' bomj') ( 60,  7.24392  ,  23, b' bomj')
#  (105,  4.60247  ,  79, b' bomj') ( 93,  1.03699  ,  18, b' bomj')
# ...

# %%
dt = np.dtype("i1, f8, i2, U10")
data2 = np.genfromtxt(data_path, delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][3]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (210,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.str_'>
# Dataset slice:
# [( 118, 8.06331 ,  69, ' bomj') (  61, 5.46451 ,   2, ' bomj')
#  ( 121, 4.47084 ,  31, ' bomj') (-114, 5.86238 , 159, ' bomj')
#  (  52, 4.32689 , 127, ' bomj') ( -79, 9.45185 ,  41, ' bomj')
#  (  25, 4.65878 , 158, ' bomj') ( -74, 9.22393 ,  99, ' bomj')
#  ( -66, 8.97034 ,   9, ' bomj') (  36, 0.756081, 138, ' bomj')]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Данные из отдельных столбцов
visota = [] # Sepal Length
dlina = [] # Sepal Width
shirina = [] # Petal Length


# Выполняем обход всей коллекции data2
for dot in data2:
    visota.append(dot[0])
    dlina.append(dot[1])
    shirina.append(dot[2])

# Строим графики по проекциям данных
# Учитываем, что каждые 70 типов ирисов идут последовательно
plt.figure(1)
bomj, = plt.plot(visota[:70], dlina[:70], 'ro', label='bomj')
musor, = plt.plot(visota[70:140], dlina[70:140], 'g^', label='musor')
bootilka, = plt.plot(visota[140:210], dlina[140:210], 'bs', label='bootilka')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('visota')
plt.ylabel('dlina')

plt.figure(2)
bomj, = plt.plot(visota[:70], shirina[:70], 'ro', label='bomj')
musor, = plt.plot(visota[70:140], shirina[70:140], 'g^', label='musor')
bootilka, = plt.plot(visota[140:210], shirina[140:210], 'bs', label='bootilka')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('visota')
plt.ylabel('shirina')

plt.figure(3)
bomj, = plt.plot(shirina[:70], dlina[:70], 'ro', label='bomj')
musor, = plt.plot(shirina[70:140], dlina[70:140], 'g^', label='musor')
bootilka, = plt.plot(shirina[140:210], dlina[140:210], 'bs', label='bootilka')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('shirina')
plt.ylabel('dlina')

plt.show()
